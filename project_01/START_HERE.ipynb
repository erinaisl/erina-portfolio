# %% [markdown]
# # wHERE?
#
# ## Missing-Person Mystery: Setting Workbook
#
# **Start here:** Double-click a cell and replace `Write here` with your own ideas. Press **Shift + Enter** when finished with a cell.
#
# You are only creating the setting right now. You do not need a culprit or solution yet.

# %% [markdown]
# ## Current premise
#
# The story begins in the missing person's office, where their laptop was left behind. They have not shown up to work for a week, which is very unusual.

# %% [markdown]
# ## 1. Where does the story happen?
#
# > Describe the workplace, city or town, and surrounding area.
#
# **My answer:**
# Office of the victim in Canandaigua, New York.

# %% [markdown]
# ## 2. Which locations matter?
#
# > List three to five places investigators might search.
#
# - Missing person's office
# - Missing person's house
# - Persons of interests houses
# - Public workspaces where the victim would work on his laptop.

# %% [markdown]
# ## 3. When does it happen?
#
# **Date or season:**
# In the Fall, on a Tuesday.
#
# **Time of day:**
# 12:00PM
#
# **Weather or special event:**
# Raining

# %% [markdown]
# ## 4. Who is missing?
#
# **Name:**
# Aaron Islas
#
# **Age:**
# 37
#
# **Job:**
# Head of Cybcersecurity Department at Thompson Hospital in Canandaigua, NY.
#
# **Personality and normal routine:**
# Dismissive, Mean, Disrespectful, Hostile

# %% [markdown]
# ## 5. Last confirmed sighting
#
# **Where and when were they last seen?**
# Stayed late at work the night before his disappearance.
#
# **Who saw them?**
# Employee, assistant, wife
#
# **Why do investigators trust this sighting?**
# These people are with him for long periods of time.

# %% [markdown]
# ## 6. Initial crime scene
#
# **What looks normal in the office?**
# Organized room, nothing messy or anything that would look like there was someone looking for something in his office.
#
# **What looks unusual?**
# His laptop was left unlocked next to his work computer.
#
# **What object attracts attention first?**
# Laptop was left logged in on work email.

# %% [markdown]
# ## 7. Possible digital evidence
#
# > Select ideas now. You will decide what they prove later.
#
# - Laptop or computer: laptop
# - Phone: missing
# - Security-camera footage: yes
# - Wi-Fi records: yes
# - Access-card records: yes
# - Messages or emails: yes!!!
# - Photos or location data: yes!!!

# %% [markdown]
# ## 8. What does not add up?
#
# > Write two facts that appear to contradict each other.
#
# **Fact one:**
# He stayed late in his office to do work, but the only thing on his desk that was unusual was his personal laptop unlocked.
#
# **Conflicting fact:**
# He said he was "working" but his personal laptop is on his desk which is the last thing that was open.

# %% [markdown]
# ## Case Timeline — First Draft
#
# ### Monday: Last confirmed day
#
# **When was Aaron last physically seen?**
# Employee stayed late at work, same time as Aaron, but left a bit earlier than him and she saw the boss last. Assisstant was told he could go home early because he wasnt needed anymore.
#
# **Who saw him, and where?**
# Employee stayed late at work, same time as Aaron, but left a bit earlier than him and she saw the boss last. Assisstant was told he could go home early because he wasnt needed anymore. Both saw him last late at the office.
#
# **What cybersecurity problem was Aaron investigating?**
# Confidential patient information from multiple people were taken from the database and moved to an unknown place elsewhere.
#
# ### Tuesday through Monday: The missing week
#
# **Why did coworkers not immediately realize Aaron was missing?**
# They initially assumed he had been sick or with his pregnant wife.
#
# **What fake emails or messages appeared during the week?**
# An email from Aaron to the hospital database center telling people he has chosen to move sosme files around.
#
# ### The following Tuesday: Investigation begins
#
# **What important meeting did Aaron miss?**
# The meeting for the cybersecurity department and what could be done better to ensure patient confidentialtiy in the digital world.
#
# **Who entered his office first?**
# His assisstant (Finn) was the first one to report after he was emailed by Aaron that he doesn't need to come in because he's not needed anymore. Finn thought it was weird to be so randomly dropped and so he dropped into the office the next day. He didnt see Aaron so he assumed he had gone home, so he tried multiple days after that. The day he called the cops was the final day he decided that this was not right for hum to be gone this long or to abrupdtly fire him.
#
# **What time was the unlocked laptop discovered?**
# When Finn came for the final time and finally became too concerned which led to him calling us.
